# %%
import matplotlib.pyplot as plt
import pickle as pkl
import numpy as np
import codecs

# %%
train_loss = np.load("train_loss.npy")
test_loss = np.load("test_loss.npy")

# %%
'''
Piece-wise regression and dynamic gamma
'''
plt.figure(figsize=(10,10))
plt.plot(train_loss)
plt.plot(test_loss)
plt.legend(["Train","Test"])
plt.grid(True)
plt.show()

# %%
#Only the nr part.
plt.figure(figsize=(10,10))
plt.plot(train_loss)
plt.plot(test_loss)
plt.legend(["Train","Test"])
plt.grid(True)
plt.show()

# %%
#Only the nr part.
plt.figure(figsize=(10,10))
plt.plot(train_loss)
plt.plot(test_loss)
plt.legend(["Train","Test"])
plt.grid(True)
plt.show()
